# %%
Today we are going to learn how to make connection between python and MySql.

# %%
import pymysql

# %%
db = pymysql.connect("localhost" , "root" , "" , "test")

# %%
#localhost ---- we r making connection locally
"root" --- mysqls user-name
"" ---- mysqls password
"test" --- db ka name

# %%
open your anaconda prompt and write 
conda install PyMySql
user name and password yaad hona chahiye mysql ka.
or mysql ki basics queries bhi aani chahiye
ref: visit w3schools/mysql pdhna basics
    select, create , where clause , insert.

# %%
import pandas as pd

# %%
df = pd.read_sql_query("select * from emp1" , db)

# %%
df
# Out:
#   first_name last_name  age   income
# 0     kavita    sharma   20   2000.0
# 1    avinesh     gupta   25  50000.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 4 columns):
# first_name    2 non-null object
# last_name     2 non-null object
# age           2 non-null int64
# income        2 non-null float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 144.0+ bytes

# %%
cursor = db.cursor()

# %%
df.to_csv("emp1.csv")

# %%
sql = "create table employee_table( id int NOT NULL, name varchar(45) NOT NULL)"

# %%
cursor.execute(sql)
# Out:
# 0

# %%
Agr suppose koi aapko bole ki data mysql k emp database k emp1 table m rakha h ?
To usko jupyter p laa sakte ho yea nhi?
Agr ek baar data aa gya jupyter p then uski basic insights find kr sakte ho
yes or no?
or visualize kr sakte ho data ko yea nhi?
joins bhi kr lena mysql m.

# %%
Numpy,Pandas,Matplotlib,seaborn,sklearn,linear regression, Distributions,ztest,ttest,chisquare test
standard error, DB k sath connection.

# %%
Web-Scraping : It is a softwae Technique to bring data from the internet or from a web-page.

# %%
.html? Kitne logo ko aati h html Sabse pehla jo hume krna hota h data ko laane k lie wo h apne web page
pr request bhejna------ request library ki help m
2.  jab page download ho gya then usko parse krna --- html tags m s data nikalna ,--- BeautifulSoup.

# %%
import requests

# %%
help(requests)
# Out:
# Help on package requests:
#
# NAME
#     requests
#
# DESCRIPTION
#     Requests HTTP Library
#     ~~~~~~~~~~~~~~~~~~~~~
#
#     Requests is an HTTP library, written in Python, for human beings. Basic GET
#     usage:
#
#        >>> import requests
#        >>> r = requests.get('https://www.python.org')
#        >>> r.status_code
#        200
#        >>> 'Python is a programming language' in r.content
#        True
#
#     ... or POST:
#
#        >>> payload = dict(key1='value1', key2='value2')
#        >>> r = requests.post('https://httpbin.org/post', data=payload)
#        >>> print(r.text)
#        {
#          ...
#          "form": {
#            "key2": "value2",
#            "key1": "value1"
#          },
#          ...
#        }
#
#     The other HTTP methods are supported - see `requests.api`. Full documentation
#     is at <http://python-requests.org>.
#
#     :copyright: (c) 2017 by Kenneth Reitz.
#     :license: Apache 2.0, see LICENSE for more details.
#
# ...

# %%
There two main methods of requests library ---- 1. get() --- to get data from server.
2.post() ---- To post something on server.
Sends a GET request.

# %%
page = requests.get("http://dataquestio.github.io/web-scraping-pages/simple.html")

# %%
page.status_code
# Out:
# 200

# %%
Status code starting from 2 indicates success and staring from 4 or 5 indicates error.

# %%
page.content
# Out:
# b'<!DOCTYPE html>\n<html>\n    <head>\n        <title>A simple example page</title>\n    </head>\n    <body>\n        <p>Here is some simple content for this page.</p>\n    </body>\n</html>'

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(page.content)

# %%
soup
# Out:
# <!DOCTYPE html>
# <html>
# <head>
# <title>A simple example page</title>
# </head>
# <body>
# <p>Here is some simple content for this page.</p>
# </body>
# </html>

# %%
soup.prettify
# Out:
# <bound method Tag.prettify of <!DOCTYPE html>
# <html>
# <head>
# <title>A simple example page</title>
# </head>
# <body>
# <p>Here is some simple content for this page.</p>
# </body>
# </html>>

# %%
Ab ye btao kon kon s tag m information yea data hai?
title or p

# %%
soup.title
# Out:
# <title>A simple example page</title>

# %%
soup.title.string
# Out:
# 'A simple example page'

# %%
soup.p.string
# Out:
# 'Here is some simple content for this page.'

# %%
print(soup.text)
# Out:
# A simple example page
#
#
# Here is some simple content for this page.

# %%
Alice in wonderlands....

# %%
html_doc = """
<html><head><title>The Dormouse's story</title></head>
<body>
<p class="title"><b>The Dormouse's story</b></p>

<p class="story">Once upon a time there were three little sisters; and their names were
<a href="http://example.com/elsie" class="sister" id="link1">Elsie</a>,
<a href="http://example.com/lacie" class="sister" id="link2">Lacie</a> and
<a href="http://example.com/tillie" class="sister" id="link3">Tillie</a>;
and they lived at the bottom of a well.</p>

<p class="story">...</p>
"""

# %%
soup = BeautifulSoup(html_doc)

# %%
soup
# Out:
# <html><head><title>The Dormouse's story</title></head>
# <body>
# <p class="title"><b>The Dormouse's story</b></p>
# <p class="story">Once upon a time there were three little sisters; and their names were
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
# <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a> and
# <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>;
# and they lived at the bottom of a well.</p>
# <p class="story">...</p>
# </body></html>

# %%
soup.a.string
# Out:
# 'Elsie'

# %%
Jab aap real time website se data fetch krte h then ek hee naaam k bht saare tags hote h
n agr aapko us sabse data fect krna h to beautifulsoup ka ek bht hee powerful function h
find_all --- jo humesha list m data return krta h

# %%
list_a = soup.find_all("a")

# %%
list_a
# Out:
# [<a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
#  <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>,
#  <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>]

# %%
print(soup.text)
# Out:
# The Dormouse's story
#
# The Dormouse's story
# Once upon a time there were three little sisters; and their names were
# Elsie,
# Lacie and
# Tillie;
# and they lived at the bottom of a well.
# ...

# %%
for links in soup.find_all('a'):
    print(links)
# Out:
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>
# <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>
# <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>

# %%
Task: ab aapko code likhna h jisme aapka output three sisters ka name aaye.
    Elsie
    Lacie
    Tillie

# %%
for x in soup.find_all("a"):
    print(x.text)
# Out:
# Elsie
# Lacie
# Tillie

# %%
wiki_link = "http://en.wikipedia.org/wiki/List_of_Asian_countries_by_area"

# %%
soup = BeautifulSoup(wiki_link)
# Out:
# C:\Anaconda3\lib\site-packages\bs4\__init__.py:335: UserWarning: "http://en.wikipedia.org/wiki/List_of_Asian_countries_by_area" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup

# %%
soup.prettify()
# Out:
# '<html>\n <body>\n  <p>\n   http://en.wikipedia.org/wiki/List_of_Asian_countries_by_area\n  </p>\n </body>\n</html>'

# %%
output = requests.get(wiki_link)

# %%
bs = BeautifulSoup(output.text)

# %%
bs.prettify()
# Out:
# '<!DOCTYPE html>\n<html class="client-nojs" dir="ltr" lang="en">\n <head>\n  <meta charset="utf-8"/>\n  <title>\n   List of Asian countries by area - Wikipedia\n  </title>\n  <script>\n   document.documentElement.className="client-js";RLCONF={"wgBreakFrames":!1,"wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgRequestId":"cc8e2bc0-b867-442d-8195-d7fa3394025a","wgCSPNonce":!1,"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":!1,"wgNamespaceNumber":0,"wgPageName":"List_of_Asian_countries_by_area","wgTitle":"List of Asian countries by area","wgCurRevisionId":963850654,"wgRevisionId":963850654,"wgArticleId":47659173,"wgIsArticle":!0,"wgIsRedirect":!1,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["Articles with short description","Articles needing additional references from January
# ...

# %%
all_tables = bs.find_all("table")

# %%
all_tables
# Out:
# [<table class="box-More_citations_needed plainlinks metadata ambox ambox-content ambox-Refimprove" role="presentation"><tbody><tr><td class="mbox-image"><div style="width:52px"><a class="image" href="/wiki/File:Question_book-new.svg"><img alt="" data-file-height="399" data-file-width="512" decoding="async" height="39" src="//upload.wikimedia.org/wikipedia/en/thumb/9/99/Question_book-new.svg/50px-Question_book-new.svg.png" srcset="//upload.wikimedia.org/wikipedia/en/thumb/9/99/Question_book-new.svg/75px-Question_book-new.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/9/99/Question_book-new.svg/100px-Question_book-new.svg.png 2x" width="50"/></a></div></td><td class="mbox-text"><div class="mbox-text-span">This article <b>needs additional citations for <a href="/wiki/Wikipedia:Verifiability" title="Wikipedia:Verifiability">verification</a></b>.<span class="hide-when-compact"> Please help <a class="external text" href="https://en.wikipedia.org/w/index.php?title=List_of_Asian_cou
# ...

# %%
countries_table = bs.find("table" , class_ = "wikitable sortable")

# %%
countries_table
# Out:
# <table class="wikitable sortable">
# <tbody><tr>
# <th>Rank
# </th>
# <th>Country
# </th>
# <th>Area (km²)
# </th>
# <th class="unsortable">Notes
# </th></tr>
# <tr>
# <td>1
# </td>
# <td><span class="flagicon" style="display:inline-block;width:25px;"><img alt="" class="thumbborder" data-file-height="600" data-file-width="900" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/en/thumb/f/f3/Flag_of_Russia.svg/23px-Flag_of_Russia.svg.png" srcset="//upload.wikimedia.org/wikipedia/en/thumb/f/f3/Flag_of_Russia.svg/35px-Flag_of_Russia.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/f/f3/Flag_of_Russia.svg/45px-Flag_of_Russia.svg.png 2x" width="23"/></span> <a href="/wiki/Russia" title="Russia">Russia</a>*
# </td>
# <td>13,000,000
# </td>
# <td>17,125,191 km² including <a href="/wiki/European_Russia" title="European Russia">European Russia</a><sup class="reference" id="cite_ref-russiaTotalAreaByCIA_1-0"><a href="#cite_note-russiaTotalAreaByCIA-1">[1]</a></sup>
# ...

# %%
Task: Fetch country name and country areafrom countries_table Hint:for loop

# %%
for tr in countries_table.find_all("tr")[1:]:
    tds = tr.find_all("td")
    print(tds[1].text,tds[2].text)
# Out:
#  Russia*
#  13,000,000
#
#  China
#  9,596,961
#
#  India
#  3,287,263
#
#  Kazakhstan*
#  2,544,900
#
#  Saudi Arabia
#  2,149,690
#
#  Indonesia*
#  1,904,569
#
#  Iran
#  1,648,195
#
#  Mongolia
#  1,564,110
#
#  Pakistan
#  881,913
#
#  Turkey*
#  759,592
#
#  Myanmar
#  676,578
#
#  Afghanistan
#  652,230
#
#  Yemen
#  527,968
#
#  Thailand
#  513,120
#
#  Turkmenistan
#  488,100
#
#  Uzbekistan
#  447,400
#
#  Iraq
#  438,317
#
#  Japan
#  377,930
#
#  Vietnam
#  331,212
#
#  Malaysia
#  330,803
#
#  Oman
#  309,500
#
#  Philippines
#  300,000
#
#  Laos
#  236,800
#
#  Kyrgyzstan
#  199,951
#
#  Syria
#  185,180
#
#  Cambodia
#  181,035
#
#  Bangladesh
#  147,570
#
#  Nepal
#  147,181
#
#  Tajikistan
#  143,100
#
#  North Korea
#  120,538
#
#  South Korea
#  100,210
#
#  Jordan
#  89,342
#
#  Azerbaijan*
#  86,000
#
#  United Arab Emirates
#  83,600
#
#  Georgia*
#  69,000
#
#  Sri Lanka
#  65,610
#
#  Bhutan
#  38,394
#
#  Taiwan
#  36,193
#
#  Armenia
#  29,843
#
#  Israel
# ...
