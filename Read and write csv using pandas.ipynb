# %%
#Writing 
dataframes - 2 dimensional, mysql table, msexcel sheets

# %%
import pandas as pd

# %%
TV = [1,3,2,1,3]
cars = [14,24,18,17,27]

# %%
df = pd.DataFrame(zip(TV,cars),columns=("TV ads","Cars Sold"))

# %%
df
# Out:
#    TV ads  Cars Sold
# 0       1         14
# 1       3         24
# 2       2         18
# 3       1         17
# 4       3         27

# %%
#i want to convert this df into csv 
df.to_csv("sales.csv")#Write object to a comma-separated values (csv) file.

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\SAKSHI\python\Pandas

# %%
sales = pd.read_csv("sales.csv")

# %%
sales
# Out:
#    Unnamed: 0  TV ads  Cars Sold
# 0           0       1         14
# 1           1       3         24
# 2           2       2         18
# 3           3       1         17
# 4           4       3         27

# %%
adv = pd.read_csv("Advertising.csv")

# %%
adv
# Out:
#      Unnamed: 0     TV  radio  newspaper  sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# 5             6    8.7   48.9       75.0    7.2
# 6             7   57.5   32.8       23.5   11.8
# 7             8  120.2   19.6       11.6   13.2
# 8             9    8.6    2.1        1.0    4.8
# 9            10  199.8    2.6       21.2   10.6
# 10           11   66.1    5.8       24.2    8.6
# 11           12  214.7   24.0        4.0   17.4
# 12           13   23.8   35.1       65.9    9.2
# 13           14   97.5    7.6        7.2    9.7
# 14           15  204.1   32.9       46.0   19.0
# 15           16  195.4   47.7       52.9   22.4
# 16           17   67.8   36.6      114.0   12.5
# 17           18  281.4   39.6       55.8   24.4
# 18           19   69.2   20.5       18.3   11.3
# ...
